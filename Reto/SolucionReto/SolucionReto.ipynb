# %% [markdown]
# # **𝓡𝓮𝓽𝓸 𝓣𝓲𝓽𝓪𝓷𝓲𝓬**
#
#
#     𝒯𝑒𝒶𝓂 𝓂𝑒𝒷𝑒𝓇𝓈
#     Nallely Serna    A00833111
#     Sofía Cantú      A01571120
#     Ozner Leyva      A01742377
#     Fernanda Perez   A01742102

# %% [markdown]
# ##1. Introduction: Explanation and Understanding of the Problem to Address
#
# The "Titanic: Machine Learning from Disaster" challenge on Kaggle aims to predict the survival of passengers aboard the RMS Titanic, based on a set of provided features. The tragic sinking of the Titanic in April 1912, which resulted in the death of more than 1,500 of the 2,224 passengers and crew, is one of the most well-known maritime disasters in modern history. (G.M., A. 2024).
#
# In this project, the goal is to develop a classification model capable of predicting whether a passenger survived or not, using machine learning techniques. The process begins with understanding and exploring the data, which includes variables such as passenger class, age, gender, number of family members aboard, among others. Exploratory data analysis (EDA) is essential to identify patterns and potential relationships between variables, which will allow for proper data preprocessing.
#
# Data preprocessing is a critical stage in this project. It involves cleaning the data, handling missing values, normalizing numerical variables, encoding categorical variables, and, in some cases, creating new features (feature engineering) that can improve the model's predictive ability.
#
# After preparing the data, the next step is selecting and training machine learning models. Since this is a binary classification problem, algorithms such as logistic regression, decision trees, Random Forest, Support Vector Machines (SVM), or more advanced models like XGBoost can be used. The choice of model is based on its performance on key metrics such as accuracy, precision, recall, and the area under the ROC curve (AUC-ROC). To determine the best model, cross-validation techniques are implemented, and hyperparameters are optimized using tools like GridSearchCV.
#
# Additionally, the importance of each variable in the final model will be evaluated, providing a clearer view of which factors were most significant for the passengers' survival. This analysis not only strengthens the model's interpretability but also enhances the understanding of the data.
#
# In summary, this project not only addresses the construction of an effective predictive model but also emphasizes the importance of data handling and careful model selection in the machine learning process. Through this exercise, technical skills are combined with in-depth data analysis to understand which features influenced the likelihood of survival in the Titanic disaster.

# %% [markdown]
# ## 2. Objectives: Concise, Measurable, and Achievable
#
#
# The main objective of this project is to develop a machine learning model capable of accurately predicting the survival probability of Titanic passengers, based on the features provided in the dataset. To achieve this goal, the following specific objectives are proposed:
#
# **1.** Conduct exploratory data analysis (EDA) to identify patterns and potential correlations between variables.
#
# **2.** Implement a data preprocessing process that includes cleaning, imputing missing values, and encoding variables.
#
# **3.** Select, train, and evaluate various classification algorithms, including logistic regression, decision trees and SVC.
#
# **4.** Do feature engineering to improve the model.
#
# **5.** Optimize model hyperparameters with Optuna to achieve hihger accuracy.
#
# **Our goal is to get 80%+ accuracy in our model as the average submit is about 78.5%.**

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ##3. Tools and Resources to Use
#
# **Kaggle**: We used Kaggle as the main work platform, offering competitions, datasets, interactive notebooks, and collaboration tools. The challenge "Titanic - Machine Learning from Disaster" was sourced from this platform and served as the foundation for our prediction project.
#
# **Google Colab**: Google Colab was employed for running Python code and training machine learning models in a cloud computing environment. This service allowed for the analysis and processing of Titanic data without the need to set up a local development environment, while also providing access to advanced computational resources such as GPUs.
#
# **Visual Studio**: For local development, we used Visual Studio Code (VS Code) as an Integrated Development Environment (IDE). It enabled project file management, external library handling, and version control, proving especially useful for organizing and testing code before running it on Google Colab.
#
# **Specific Libraries and Frameworks**:
#
# **Pandas and NumPy**: Used for data processing and analysis, enabling structured manipulation of large data volumes.
#
# **Matplotlib and Seaborn**: Employed for data visualization and charts, essential for exploratory analysis and visual representation of results.
#
# **Scikit-learn (sklearn)**:
#
# **Evaluation Metrics**: Modules like sklearn.metrics were used to compute evaluation metrics, including accuracy_score, roc_auc_score, confusion_matrix, and classification_report.
# Machine Learning Models: Several algorithms were implemented using sklearn, including logistic regression (linear_model), decision trees and random forests (ensemble, tree), k-nearest neighbors (neighbors), and support vector machines (svm).
# Preprocessing and Cross-validation: We utilized data preprocessing tools (preprocessing) and cross-validation techniques (model_selection).
# CatBoost: The CatBoostClassifier algorithm was used to improve model performance by efficiently handling categorical data.
#
# **Optuna**: This library was used for hyperparameter optimization, allowing us to find the most optimal configurations for the trained models.
#
# **Hardware and Services**:
#
# Google Colab provided access to high-performance hardware resources, such as GPUs (Graphics Processing Units), to accelerate the training of machine learning models. This enabled faster and more efficient simulations and training without the need for local infrastructure.
#
# **Information Sources**:
#
# The data used was obtained from Kaggle, which provided a structured dataset from the famous Titanic disaster. This data included demographic characteristics of passengers (age, gender, ticket class, etc.) in CSV format, and it was of high quality and sufficiently extensive for statistical analysis and predictive modeling.

# %% [markdown]
# ##4. Stages (Data Science Life Cycle):
#
#
# For imputing **Age**, four different methods were attempted:
#
# - **KNN** (finds the 10 nearest neighbors based on related features such as Pclass, SibSp, Parch, Fare, and Sex, and uses the age values of these neighbors to predict the missing age of a record).
#   - Model accuracy: **0.7942583732057417%**
#
# - **By title** (extracts the title from the names (Mr., Miss., Mrs., etc.), groups them along with the variables Pclass (ticket class) and Sex (gender), then calculates the median age for each group).
#   - Model accuracy: **0.784688995215311%**
#
# - **Merge**, combines titles and KNN.
#   - Model accuracy: **0.7942583732057417%**
#
# - **Median** (median of all values).
#   - Model accuracy: **0.7990430622009569%**
#
# Due to the better precision provided, we chose the **"Median"** method for imputing **Age**.

# %% [markdown]
# ##5. Results
#
# The CatBoostClassifier model, optimized through Optuna, achieved an accuracy of 0.806 on the test set, indicating competitive performance in predicting the survival of Titanic passengers. During the exploratory data analysis phase, important patterns were identified, such as the correlation between ticket price (fare) and survival, as well as the relationship between age and survival rates. For example, children under 10 years old had a higher probability of survival compared to adults. Additionally, passengers traveling in first class and those with higher fares showed higher survival rates. The final model was trained using the best hyperparameters determined by the Optuna optimization process, which significantly improved its performance.

# %% [markdown]
# ##6. Conclusions and Future Work:
#
# The model built to predict the survival of Titanic passengers shows promising results, but there are areas that could be improved. The main area for improvement includes addressing class imbalance in the dataset, as non-survivors represent a significantly larger proportion. Class balancing techniques, such as oversampling or undersampling, could be explored to improve the model's sensitivity toward surviving passengers. Additionally, creating new derived features (feature engineering) could increase the model's predictive capability. Finally, it is recommended to explore other advanced models, such as model ensembles or deep learning techniques, to compare their performance with traditional machine learning models.

# %% [markdown]
# ##7.References
#
#
#
#
#
#
#
#
# G.M., A. (2024). El Titanic, la historia completa de un naufragio histórico. National Geographic Historia. https://historia.nationalgeographic.com.es/a/historia-titanic-tragedia-barco-insumergible_16344
#
#
#
# Will Cukierski. (2012). Titanic - Machine Learning from Disaster. Kaggle. https://kaggle.com/competitions/titanic

# %% [markdown]
# ## **Import libraries**

# %%
# !pip install -q  pandas scikit-learn catboost numpy matplotlib seaborn optuna

# Data processing and analysis libraries
import pandas as pd
import numpy as np
import re
from google.colab import files

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluation metrics
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

# Machine learning models
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# Preprocessing and cross validation
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_val_predict

# CatBoost for boosting models
from catboost import CatBoostClassifier, Pool, cv

# Optimization
import optuna

#Eliminate warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Exploratory Analysis**

# %% [markdown]
# Function: This line of code displays the first 5 rows of the DataFrame df, allowing you to observe the initial entries and better understand the structure of the dataset.
#
# Expected Output: The output is a table showing the first 5 rows of the dataset, including the column names and the corresponding values for each row.

# %%
df = pd.read_csv('train.csv', index_col=0)

#The first 5 rows of the dataset to understand its structure
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ---
#
#
# Function: This line of code generates and displays descriptive statistics for the numerical variables in the DataFrame df.
#
# Expected Output: The output is a summary table that includes statistics such as count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile, Q2), 75th percentile (Q3), and maximum for each numerical column in the dataset.

# %%
#Stats for numerical variables
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Key Observations:
#
# Data Missingness: The Age column has missing values, which is critical information because you may need to handle this missing data appropriately during preprocessing.
#
# Survival Correlation: The survival rate is less than half, and it might be interesting to explore how different factors like Pclass, Age, SibSp, Parch, and Fare correlate with survival.
#
# Skewness: The wide range and high standard deviation in the Fare column suggest that it might be skewed, which could influence the model if not properly addressed.
#
# ---

# %% [markdown]
# Function: This code calculates the percentage of missing values in each column of the DataFrame df.
#
# **df.isnull().mean():** Computes the proportion of missing values for each column.
#
# **.round(4) * 100:** Rounds these proportions to four decimal places and converts them to percentages.
#
# **missing_values = missing_values[missing_values > 0]:** Filters out columns that have no missing values (i.e., keeps only those columns with missing values).
#
# Expected Output: A Series where the index represents the column names and the values represent the percentage of missing data for those columns that have missing values. This helps you identify which columns have missing data and the extent of the missingness.

# %%
# Percentage of missing values in the columns
missing_values = df.isnull().mean().round(4) * 100
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# Age         19.87
# Cabin       77.10
# Embarked     0.22
# dtype: float64

# %% [markdown]
# Key Insights:
#
# Significant Missing Data: The Cabin column has a very high percentage of missing data, which may pose challenges. Deciding how to handle this will be important for your model.
#
# Moderate Missing Data: The Age column also has a notable amount of missing data, which could influence predictions and needs careful handling.
#
# Minimal Missing Data: The Embarked column has negligible missing data, which can be easily addressed.
#
#
#
# ---

# %% [markdown]
# Function: This code uses Seaborn to create a count plot that visualizes the distribution of the Survived variable in the DataFrame df.
#
# Expected Output: A bar plot showing the number of passengers who survived (1) and those who did not survive (0). This visualization helps you understand the proportion of survivors versus non-survivors in the dataset.

# %%
#Survival Distribution
sns.countplot(x='Survived', data=df)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2, p.get_height() + 0.5, int(p.get_height()), ha='center')
plt.title('Survival Distribution (0 = No, 1 = Yes)')
plt.show()

# %% [markdown]
# Key Insights:
#
# Imbalance in the Target Variable: The plot highlights that the dataset has an imbalanced distribution between survivors and non-survivors, with more passengers not surviving.
#
#
# ---

# %% [markdown]
# Expected Output:
#
# A bar plot that shows the number of passengers in each class (1st, 2nd, and 3rd). The x-axis represents the Pclass categories (1, 2, and 3), and the y-axis represents the count of passengers in each class.

# %%
# Distribution of varieble: 'Pclass'
sns.countplot(x='Pclass', data=df)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2, p.get_height() + 0.5, int(p.get_height()), ha='center')
plt.title('Passenger Class Distribution')
plt.show()

# %% [markdown]
# Analysis:
#
# Class Imbalance:
#
# The 3rd class has significantly more passengers than the 1st and 2nd classes combined. This indicates a strong imbalance in the distribution of passengers across different classes. Specifically, more than half of the passengers were in the 3rd class, suggesting that the majority of the passengers were from a lower socio-economic background.
#
# Implications for Survival:
#
# Historical data and analysis of the Titanic dataset often show that survival rates were higher for 1st class passengers compared to those in 2nd and 3rd classes. Given that the majority of passengers were in 3rd class, this could suggest that a larger proportion of the passengers were at a disadvantage when it came to survival. This distribution could lead to a lower overall survival rate because a higher number of passengers were in the class with presumably the lowest survival rate.
#
#
# ---

# %% [markdown]
# Expected Output:
#
# A histogram with 30 bins showing the distribution of passengers' ages, overlaid with a KDE curve that smooths out the distribution. The x-axis represents the age of passengers, and the y-axis shows the frequency (or count) of passengers within each age bin.

# %%
# Age distribution
sns.histplot(df['Age'].dropna(), kde=True, bins=30)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2, p.get_height() + 0.5, int(p.get_height()), ha='center')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# Key Observations:
#
# Age Distribution:
#
#   Shape: The distribution is right-skewed, with more younger passengers than older ones. Most passengers are between 20 and 40 years old, peaking around age 20.
#   Mode: The highest peak indicates that most passengers were in their twenties.
#
#
# KDE (Kernel Density Estimation):
#
#   Smoothed Curve: The blue KDE curve smooths out the distribution, highlighting the general trend without the noise of bin variations.
#   Trend: It shows a high concentration of younger passengers, with a gradual decline in older age groups.
#
#
# Passenger Frequency:
#
#   Y-Axis (Frequency): The Y-axis shows the count of passengers within each age bin, with the highest frequency around age 20.
#
# Bins:
#
#   Number of Bins: The 30 bins provide a detailed view of the age distribution, balancing detail and smoothness.
#
#
#
# ---

# %% [markdown]
# Expected Result:
# A bar plot comparing the survival rates of male and female passengers on the Titanic.
#
# The x-axis shows the survival status (0 for not survived, 1 for survived), and the y-axis indicates the count of passengers.
#
# The bars are color-coded by gender, with dark cyan representing males and aquamarine representing females.

# %%
# Survival comparison by gender
custom_palette = ['darkcyan', 'aquamarine']
sns.countplot(x='Survived', hue='Sex', data=df, palette=custom_palette)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2,
             p.get_height() + 0.5,
             int(p.get_height()),
             ha='center')
plt.title('Survival by Gender')
plt.show()

# %% [markdown]
# Survival by Gender:
#
# Males (dark cyan):
# A large number of male passengers did not survive (left bar).
#
# A significantly smaller number of males survived (right bar).
#
# Females (aquamarine):
# Fewer female passengers did not survive compared to males.
#
# A higher count of female passengers survived, surpassing the number of male survivors.
#
#
#
# Gender Comparison:
#
# The graph clearly shows that women had a much higher survival rate compared to men.
#
# This difference is likely due to the "women and children first" policy followed during the Titanic's evacuation.
#
#
#
# ---

# %% [markdown]
# Expected Result:
#
# A bar plot showing the survival rates of passengers across different classes on the Titanic. The x-axis represents survival status (0 for not survived, 1 for survived), and the y-axis shows the count of passengers.
#
# The bars are color-coded based on the passenger class (Pclass), with dark cyan representing first class, aquamarine for second class, and light slate grey for third class.

# %%
# Survival comparison by class
custom_palette = ['darkcyan', 'aquamarine', 'lightslategrey']
sns.countplot(x='Survived', hue='Pclass', data=df, palette=custom_palette)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2,
             p.get_height() + 0.5,
             int(p.get_height()),
             ha='center')
plt.title('Survival by Class')
plt.show()

# %% [markdown]
# Survival by Class:
#
# First Class (dark cyan):
#
# First-class passengers had a higher survival count compared to other classes.
#
# Fewer first-class passengers did not survive.
#
# Second Class (aquamarine):
#
# The survival count for second-class passengers is lower than first class but higher than third class.
#
# The number of non-survivors is almost equal to the number of survivors.
#
# Third Class (light slate grey):
#
# The majority of third-class passengers did not survive.
#
# The survival count for third-class passengers is the lowest among all classes.
#
#
# Class Comparison:
#
# First-class passengers had a significantly higher chance of survival, possibly due to their privileged access to lifeboats.
#
# Third-class passengers faced the highest mortality rate, highlighting the disparities in survival chances based on class.
#
#
# ---

# %%
# Analysis of the fare paid
sns.histplot(df['Fare'], kde=True, bins=30)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2,
             p.get_height() + 0.5,
             int(p.get_height()),
             ha='center')
plt.title('Fare Distribution')
plt.show()

# %% [markdown]
# Fare Distribution:
#
# The fare distribution for Titanic passengers is heavily right-skewed, with most passengers paying lower fares and a small group paying significantly higher amounts, indicating the presence of different socioeconomic classes. This distribution could impact survival analysis, as higher fares might be associated with a higher likelihood of survival.
# Given that fare could be correlated with passenger class and therefore socioeconomic status, this variable may play a significant role in survival analysis.

# %%
# Survival comparison by embarkation port
custom_palette = ['darkcyan', 'aquamarine', 'lightslategrey']
sns.countplot(x='Survived', hue='Embarked', data=df, palette=custom_palette)
for p in plt.gca().patches:
    plt.text(p.get_x() + p.get_width() / 2,
             p.get_height() + 0.5,
             int(p.get_height()),
             ha='center')
plt.title('Survival by Embarkation Port')
plt.show()

# %% [markdown]
# Survival by Embarkation Port:
#
# The majority of passengers embarked from port 'S' (Southampton), followed by 'C' (Cherbourg) and 'Q' (Queenstown).
#
# Passengers who embarked from Cherbourg ('C') appear to have a higher survival rate compared to those from Southampton ('S') and Queenstown ('Q').

# %%
# Correlation matrix between numerical variables
plt.figure(figsize=(10, 8))
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Correlation matrix (between numerical variables):
#
# Fare shows a moderate positive correlation with survival (r = 0.26), indicating that passengers who paid higher fares had a slightly higher chance of survival.
#
# Pclass has a moderate negative correlation with survival (r = -0.34), suggesting that passengers in lower classes (higher Pclass values) were less likely to survive.
#
# SibSp and Parch show a moderate positive correlation (r=0.41), indicating that passengers with more siblings/spouses on board also tended to have more parents/children with them.
#
# The correlation matrix reveals that higher fares and lower class numbers are associated with better survival chances, while inter-feature correlations like that between SibSp and Parch highlight family structures on board.

# %%
# Survival Rate by Embarkation Port
survivors_by_port = df.groupby('Embarked')['Survived'].mean()
ax = survivors_by_port.plot(kind='bar', color=['darkcyan', 'aquamarine', 'lightslategrey'])
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')
plt.title('Survival Rate by Embarkation Port')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# Survival Rate by Embarkation Port:
#
# Passengers who embarked from Cherbourg have the highest survival rate at 55%.
#
# The survival rate for passengers who embarked from Queenstown is 39%, placing it in the middle among the three ports.
#
# Passengers who embarked from Southampton have the lowest survival rate at 34%

# %%
# look if there is any correlation between the ticket price and survival
ax = sns.boxplot(x='Survived', y='Fare', data=df)
n_obs = df.groupby('Survived').size()
for i, label in enumerate(n_obs):
    ax.text(i, df['Fare'].max() + 10, f'N={label}', horizontalalignment='center')
plt.title('Survival by Fare')
plt.show()

# %% [markdown]
# look if there is any correlation between the ticket price and survival:
#
# Passengers who survived (Survived = 1) generally paid higher fares compared to those who did not survive (Survived = 0).
#
# The median fare for survivors is notably higher than for non-survivors, suggesting that passengers who paid more for their tickets, likely in higher classes, had a better chance of survival.
#
# Passengers who paid higher fares tended to survive at a greater rate than those who paid lower fares, reflecting the influence of social class on survival.

# %%
# Correlation betwwen the ticket price and the survival rate
fare_survival = df.groupby('Survived')['Fare'].mean()
ax = fare_survival.plot(kind='bar', color=['darkcyan', 'aquamarine'])
n_obs = df.groupby('Survived').size()
for i, count in enumerate(n_obs):
    ax.text(i, fare_survival[i] + 5, f'N={count}', ha='center')
plt.title('Average Fare by Survival')
plt.ylabel('Average Fare')
plt.show()

# %% [markdown]
# Average Fare by Survival:
#
# Passengers who survived (Survived = 1) paid a significantly higher average fare, around 50 units, compared to non-survivors (Survived = 0), whose average fare was approximately 22 units.
#
# The number of non-survivors is 549, whereas 342 passengers survived. This imbalance in the dataset could also be a factor in survival rates, with wealthier passengers (who paid higher fares) possibly receiving priority.

# %%
# Chance of survival by age

# Create a KDE plot
plt.figure(figsize=(10, 5))

n_survived_0 = len(df[df['Survived'] == 0])
n_survived_1 = len(df[df['Survived'] == 1])
sns.kdeplot(data=df[df['Survived'] == 0], x="Age", fill=True, label=f'No Survivors (N={n_survived_0})', color="lightslategrey", alpha=0.4)
sns.kdeplot(data=df[df['Survived'] == 1], x="Age", fill=True, label=f'Survivors (N={n_survived_1})', color="darkcyan", alpha=0.4)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Chance of survival by age')

# Add legend
plt.legend(title='Survived')

# Show plot
plt.show()

# %% [markdown]
# Chance of survival by age:
#
# Both survivors and non-survivors have similar age distributions, with most passengers falling between 20 and 40 years old.
#
# The peak density for non-survivors occurs around age 25, while survivors show a broader distribution between ages 20 and 40.
#
# Passengers younger than 10 years old have a higher density in the survivor group compared to non-survivors
#
# After 40y almost is almost 50 - 50 the number of people that have survived and the number of people that have died.
#
# In the 40 to 60 age range, the densities for both survivors and non-survivors are quite similar
#
# Younger passengers (particularly children) had a higher survival rate compared to adults, which aligns with historical data about the prioritization of women and children during the Titanic disaster.

# %%
# With family or alone
df['Family'] = np.where(df['SibSp'] + df['Parch'] > 0, "With Family", "Alone")
ax = sns.countplot(x='Survived', hue='Family', data=df)
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')
plt.title('Survival by Family')
plt.show()

# %% [markdown]
# Survival by Family:
#
# Passengers who were with family show a relatively balanced survival rate, with 179 survivors and 175 non-survivors. Indicating that having family on board did not significantly affect survival in a positive or negative direction, as the number of survivors and non-survivors is quite close.
#
# Passengers who were alone were more likely to not survive.
#
# Passengers who traveled alone were less likely to survive compared to those who were with family, who had nearly equal chances of survival and non-survival

# %% [markdown]
# ## **Cleaning the data**

# %% [markdown]
# First of all, the data must be observed. Looking at the dataset information, we can see which are the types of values we are going to work with and which of the data we are interested in will require an imputation method to be applied to them.
#
# We are not going to remove outliers for a simple reason, we don't even know the reason whay they are outliers.
#
# The porpuse of the model should be to aproximate the reality of a phenomenom, so we are not going to remove outliers if we don't the nature of them.
#
# If you are a person to tend to remove outliers no matter what or due model assumptions, don't worry, we also did some tests removing the outliers and the accuracy of the model did not increase.
#
# 80.6% dropped to 79.2% when we removed outliers in the 'Fare' and 'Age' using 3 standard deviations. I f you only remove the outliers in 'Fare' the accuracy would be the same (80.6%).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
#  11  Family    891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 90.5+ KB

# %%
df["Age"].hist(bins=50, color='darkcyan', alpha=0.7)
# Out:
# <Axes: >

# %% [markdown]
# We will use the median to fill the null values in Age

# %% [markdown]
# Let's see if we can normalize the distribution with Log

# %%
df["Log_Age"] = np.log1p(df["Age"])
df["Log_Age"].hist(bins=50, color='darkcyan', alpha=0.7)
# Out:
# <Axes: >

# %% [markdown]
# Definitely not normal.
#
# But at least we are gona make the distribution zero-mean.

# %%
df["Age"] = df["Age"].apply(lambda x: x - 30)
df["Age"].hist(bins=50, color='darkcyan', alpha=0.7)
# Out:
# <Axes: >

# %%
df["Fare"].hist(bins=50, color='darkcyan', alpha=0.7)
# Out:
# <Axes: >

# %% [markdown]
# We will use the median to fill the null values in Fare, but gruping it by Pclass so it makes more sense. People on the same class tend pay similar prices.

# %%
df["Embarked"].hist(bins=50, color='darkcyan', alpha=0.7)
# Out:
# <Axes: >

# %% [markdown]
# We will use mode to fill the null values in Embarked.

# %% [markdown]
# **We know that there is 77.1% of missing data in the 'cabin' column, we tried to fill it using a knn model but we did not have a good accuracy, then we decided to try with random forest, and after several more attempts we decided to eliminate the 'cabin' column as we did not get the expected results to fill this column and it did not add something good to our results so it is better not to use the column.**

# %% [markdown]
# ## **Model Selection**

# %% [markdown]
# Note that we are going to use a test data that also has the true answers (y_test) of the titanic problem. Therefore we can calculate the accuracy without kaggle.

# %% [markdown]
# We are going to compare some basic models for this type of problems, due the amount of categorical variables we will also include CatBoost into the comparison of models.
#
# We won't use neural networks due the small amount of data we have.

# %% [markdown]
# ##### The models we will test are:
# - Decision Trees: A simple, interpretable model that splits the data based on feature values to make decisions. Useful to identify some patterns in the data.
# - Random Forest: An ensemble of decision trees that reduces overfitting by averaging the predictions of multiple trees. It’s more robust and generally performs better than a single decision tree.
# - Logistic Regression: A simple linear model that predicts the probability of an outcome. It’s a good baseline model for binary classification problems.
# - CatBoost: A gradient boosting algorithm specifically designed for categorical data, often outperforming other models in terms of accuracy and handling categorical features effectively.
# - Support Vector Machine: A powerful model that works well in high-dimensional spaces and is effective in cases where the number of dimensions is greater than the number of samples. It’s particularly useful for classification problems with clear margins of separation.

# %%
def basic_preprocess_data(data):
    data.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
    data['Age'].fillna(data['Age'].median(), inplace=True)
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
    data['Fare'].fillna(data['Fare'].median(), inplace=True)
    data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})
    data = pd.get_dummies(data, columns=['Embarked'])
    return data

def compare_models(train, test, X_train, y_train, X_test, y_test):

    train.columns = train.columns.str.lower()
    test.columns = test.columns.str.lower()

    features = X_train
    target = y_train

    train_for_cat = train.copy()
    test_for_cat = test.copy()
    train_features_for_cat = train_for_cat.drop('survived', axis=1)
    train_target_for_cat = train_for_cat['survived']
    test_features_for_cat = test_for_cat.drop('survived', axis=1)
    test_target_for_cat = test_for_cat['survived']

    features_index = np.where(train_features_for_cat.dtypes != float)[0]

    cat = CatBoostClassifier(loss_function='Logloss',
                         eval_metric='Accuracy',
                         random_seed=42,
                         verbose=False)

    cat.fit(train_features_for_cat, train_target_for_cat, cat_features=features_index)

    x_train_for_cat = train_features_for_cat
    x_test_for_cat = test_features_for_cat
    y_train_for_cat = train_target_for_cat
    y_test_for_cat = test_target_for_cat

    cat_features_index = np.where(train_features_for_cat.dtypes != float)[0]

    dct_with_models = {}

    for label_model, model in {'RF': [RandomForestClassifier(random_state=42), 'no_scaler'],
                            'DT': [DecisionTreeClassifier(random_state=42), 'no_scaler'],
                            'LR': [LogisticRegression(random_state=42), 'need_scaler'],
                            'KNB': [KNeighborsClassifier(), 'need_scaler'],
                            'SVC': [SVC(random_state=42, probability=True), 'need_scaler'],
                            'CAT': [CatBoostClassifier(loss_function='Logloss', eval_metric='Accuracy', verbose=False, use_best_model=True, random_seed=42), 'cat']}.items():


        if model[1] == 'need_scaler':
            scaled_features = StandardScaler().fit_transform(features)
            scores = cross_val_score(model[0], scaled_features, target, cv=9, scoring='accuracy')
            scaler = StandardScaler()
            scaled_train = scaler.fit_transform(X_train)
            scaled_test = scaler.transform(X_test)
            model[0].fit(scaled_train, y_train)
            dct_with_models[f'{label_model}_overall_accuracy_for_model_for_dataset'] = np.mean(scores)
            dct_with_models[f'{label_model}_accuracy_for_x_test_with_default_params'] = accuracy_score(y_test, model[0].predict(scaled_test))
            dct_with_models[f'{label_model}_roc_auc_for_x_test_with_default_params'] = roc_auc_score(y_test, model[0].predict_proba(scaled_test)[:,1])

        elif model[1] == 'no_scaler':
            scores = cross_val_score(model[0], features, target, cv=9, scoring='accuracy')
            model[0].fit(X_train, y_train)
            dct_with_models[f'{label_model}_overall_accuracy_for_model_for_dataset'] = np.mean(scores)
            dct_with_models[f'{label_model}_accuracy_for_x_test_with_default_params'] = accuracy_score(y_test, model[0].predict(X_test))
            dct_with_models[f'{label_model}_roc_auc_for_x_test_with_default_params'] = roc_auc_score(y_test, model[0].predict_proba(X_test)[:,1])

        elif model[1] == 'cat':
            scores = cv(Pool(train_features_for_cat, train_target_for_cat, cat_features=cat_features_index),
                        {"loss_function": "Logloss",
                        "eval_metric": "Accuracy",
                        "verbose": False,
                        "random_seed": 42},
                        fold_count=5)
            model[0].fit(x_train_for_cat, y_train_for_cat,
                        cat_features=cat_features_index,
                        eval_set=(x_test_for_cat, y_test_for_cat),
                        verbose=True,
                        plot=False)
            dct_with_models[f'{label_model}_overall_accuracy_for_model_for_dataset'] = scores['test-Accuracy-mean'].mean()
            dct_with_models[f'{label_model}_accuracy_for_x_test_with_default_params'] = accuracy_score(y_test_for_cat, model[0].predict(x_test_for_cat))
            dct_with_models[f'{label_model}_roc_auc_for_x_test_with_default_params'] = roc_auc_score(y_test_for_cat, model[0].predict_proba(x_test_for_cat)[:,1])
    model = []
    overall_accuracy_for_dataset = []
    accuracy_for_x_test_with_default_params = []
    roc_auc_for_x_test_with_default_params = []

    for name_model in ['DT', 'RF', 'LR', 'KNB', 'SVC', 'CAT']:
        model.append(name_model)
        overall_accuracy_for_dataset.append(dct_with_models[f'{name_model}_overall_accuracy_for_model_for_dataset'])
        accuracy_for_x_test_with_default_params.append(dct_with_models[f'{name_model}_accuracy_for_x_test_with_default_params'])
        roc_auc_for_x_test_with_default_params.append(dct_with_models[f'{name_model}_roc_auc_for_x_test_with_default_params'])

    results = {
    'Model' : model,
    'OVERALL ACCURACY FOR TRAIN DATASET' : pd.Series(overall_accuracy_for_dataset),
    'ROC_AUC FOR X_TEST WITH DEFAULT PARAMS' : pd.Series(roc_auc_for_x_test_with_default_params),
    'ACCURACY FOR X_TEST WITH DEFAULT PARAMS' : pd.Series(accuracy_for_x_test_with_default_params)}

    display(pd.DataFrame(results).style.highlight_max(color='green'))

# %%
train = pd.read_csv("train.csv", index_col=0)
train = basic_preprocess_data(train)

y_train = train['Survived']
X_train = train.drop('Survived', axis=1)

len(X_train), len(y_train)
# Out:
# (891, 891)

# %%
test = pd.read_csv('test_with_survived.csv', index_col=0)
test = basic_preprocess_data(test)

y_test = test['Survived']
X_test = test.drop(["Survived"], axis=1)

len(X_test), len(y_test)
# Out:
# (418, 418)

# %%
compare_models(train, test, X_train, y_train, X_test, y_test)
# Out:
# Training on fold [0/5]
#
# bestTest = 0.8100558659
# bestIteration = 13
#
# Training on fold [1/5]
#
# bestTest = 0.8882681564
# bestIteration = 60
#
# Training on fold [2/5]
#
# bestTest = 0.8595505618
# bestIteration = 1
#
# Training on fold [3/5]
#
# bestTest = 0.7865168539
# bestIteration = 130
#
# Training on fold [4/5]
#
# bestTest = 0.8192090395
# bestIteration = 188
#
# Learning rate set to 0.030798
# 0:	learn: 0.8226712	test: 0.7775120	best: 0.7775120 (0)	total: 3.64ms	remaining: 3.63s
# 1:	learn: 0.8193042	test: 0.7751196	best: 0.7775120 (0)	total: 7.57ms	remaining: 3.77s
# 2:	learn: 0.8204265	test: 0.7727273	best: 0.7775120 (0)	total: 10.8ms	remaining: 3.59s
# 3:	learn: 0.8193042	test: 0.7751196	best: 0.7775120 (0)	total: 14.8ms	remaining: 3.69s
# 4:	learn: 0.8170595	test: 0.7751196	best: 0.7775120 (0)	total: 17.7ms	remaining: 3.52s
# 5:	learn: 0.8260382	test: 0.7751196	best: 0.7775120 (0)	total: 21.7ms	remaining: 3.59s
# ...

# %% [markdown]
# As we can see, CatBoost and SVM are the best models for this problem. But catboost has better accuracy in out-of-sample data so we will use CatBoost as our base model for the moment.

# %% [markdown]
# Data Preprocessing Function

# %%
def preprocess_data(data):

    data.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

    data['Age'].fillna(data['Age'].median(), inplace=True)
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
    data['Fare'].fillna(data['Fare'].median(), inplace=True)
    data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})
    data["Age"] = data["Age"].apply(lambda x: x - 30)
    data = pd.get_dummies(data, columns=['Embarked'])

    return data

# %% [markdown]
# ## **Prepare the Data**

# %%
train = pd.read_csv("train.csv", index_col=0)
train = preprocess_data(train)

y_train = train['Survived']
X_train = train.drop('Survived', axis=1)

len(X_train), len(y_train)
# Out:
# (891, 891)

# %%
test = pd.read_csv('test_with_survived.csv', index_col=0)
test = preprocess_data(test)

y_test = test['Survived']
X_test = test.drop(["Survived"], axis=1)

len(X_test), len(y_test)
# Out:
# (418, 418)

# %% [markdown]
# ## **Model**

# %% [markdown]
# We will use catboost, therefore we need to indicate the categorical features.

# %%
X_train.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_C',
#        'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
cat_features = np.where(X_train.dtypes != float)[0]
cat_features
# Out:
# array([0, 1, 3, 4, 6, 7, 8])

# %% [markdown]
# In Catboost models we don't need to make any transformation to categorical variables, this model can handle it automatically, in fact, we can input text in our model and there will be no problem.
#
# Also, this model not need normalization of the numerical variables, so we will not do it.

# %% [markdown]
# Create the Model

# %%
# Fit the model
model = CatBoostClassifier(loss_function='Logloss', eval_metric='Accuracy', verbose=False, use_best_model=True, random_seed=42, cat_features=cat_features)
model.fit(X_train, y_train, eval_set=(X_test, y_test))

# Make predictions
y_pred = model.predict(X_test)

# Evaluate predictions
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7990430622009569

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85       260
#            1       0.77      0.66      0.71       158
#
#     accuracy                           0.80       418
#    macro avg       0.79      0.77      0.78       418
# weighted avg       0.80      0.80      0.80       418

# %%
plt.figure(figsize = (4,4))
cm = sns.heatmap(confusion_matrix(y_test, y_pred), fmt='g', annot=True)
cm.set(title='Confusion Matrix')
cm.set(xlabel='Predicted', ylabel='Actual')
plt.show()

# %%
# Get the feature importance
feature_importance = model.get_feature_importance(prettified=True)
feature_importance
# Out:
#    Feature Id  Importances
# 0         Sex    42.971406
# 1      Pclass    18.585748
# 2         Age    11.570046
# 3        Fare     9.734781
# 4       SibSp     7.140632
# 5       Parch     6.359841
# 6  Embarked_S     1.829718
# 7  Embarked_C     1.089721
# 8  Embarked_Q     0.718109

# %% [markdown]
# ### *Try with different inputations of Age*

# %% [markdown]
# **Imputation based on KNN (K-Nearest Neighbors)**

# %%
def impute_age_KNN(data):

    # Selection of relevant features to find nearby neighbors
    age_features = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Sex']

    # Subset of characteristics and age column
    age_data = data[age_features + ['Age']].copy()

    # Coding categorical variables
    le = LabelEncoder()
    age_data['Sex'] = le.fit_transform(age_data['Sex'])

    # Make sure that all columns are numeric.
    age_data = age_data.apply(pd.to_numeric, errors='coerce')

    # Create the KNN imputator
    imputer = KNNImputer(n_neighbors=10, weights='uniform')

    # Impute missing values in 'Age'.
    age_imputed = imputer.fit_transform(age_data)

    # Create a new DataFrame with the imputed values
    age_imputed_df = pd.DataFrame(age_imputed, columns=age_data.columns, index=age_data.index)

    # Assign the imputed values of 'Age' back to the original DataFrame
    data.loc[age_data.index, 'Age'] = age_imputed_df['Age']

    return data

# %%
# New preprocess data with new imputation function
def age_imp_preprocess_data_KNN(data):
    data = impute_age_KNN(data)
    data.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
    data['Fare'].fillna(data['Fare'].median(), inplace=True)
    data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})
    data = pd.get_dummies(data, columns=['Embarked'])
    return data

# %%
train = pd.read_csv("train.csv", index_col=0)
train = age_imp_preprocess_data_KNN(train)

y_train = train['Survived']
X_train = train.drop('Survived', axis=1)

test = pd.read_csv('test_with_survived.csv', index_col=0)
test = age_imp_preprocess_data_KNN(test)

y_test = test['Survived']
X_test = test.drop(["Survived"], axis=1)

cat_features = np.where(X_train.dtypes != float)[0]

model = CatBoostClassifier(loss_function='Logloss', eval_metric='Accuracy', verbose=False, use_best_model=True, random_seed=42, cat_features=cat_features)
model.fit(X_train, y_train, eval_set=(X_test, y_test))

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7942583732057417

# %% [markdown]
# **Imputation based on title, class and gender**

# %%
def impute_age_title(data):

    # Make sure that the column 'Name' exists in the DataFrame.
    if 'Name' not in data.columns:
        raise KeyError("The column 'Name' does not exist in the DataFrame.")

    # Convert all strings in the 'Name' column to lowercase
    data['Name'] = data['Name'].str.lower()

    # Function to extract the title from the name
    def give_title(row):
        title = str(re.split(r'[,.]+', row['Name'])[1]).strip()
        return title

    # Applying the give_title function to extract titles
    data['Title'] = data.apply(give_title, axis=1)

    # Replace equivalent titles to unify
    data.replace({'Title': {'mlle': 'miss', 'ms': 'miss', 'mme': 'mrs'}}, inplace=True)

    label_encoder = LabelEncoder()
    data['Title'] = label_encoder.fit_transform(data['Title'])

    # Function to impute age based on title, class and gender
    def give_age(row, df):
        age = row['Age']
        if pd.isna(age):
            title = row['Title']
            pclass = row['Pclass']
            sex = row['Sex']
            # Impute using the median of 'age' based on 'title', 'pclass', and 'sex'.
            age = df[(df['Title'] == title) & (df['Pclass'] == pclass) & (df['Sex'] == sex)]['Age'].median()
            # If no median is found, try with only 'pclass' and 'sex'.
            if pd.isna(age):
                age = df[(df['Pclass'] == pclass) & (df['Sex'] == sex)]['Age'].median()
        return age

    # Apply the give_age function to each row of the DataFrame
    data['Age'] = data.apply(lambda row: give_age(row, data), axis=1)

    return data

# %%
# New preprocess data with new imputation function
def age_imp_preprocess_data_title(data):
    data = impute_age_title(data)
    data.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
    data['Fare'].fillna(data['Fare'].median(), inplace=True)
    data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})
    data = pd.get_dummies(data, columns=['Embarked'])
    return data

# %%
train = pd.read_csv("train.csv", index_col=0)
train = age_imp_preprocess_data_title(train)

y_train = train['Survived']
X_train = train.drop('Survived', axis=1)

test = pd.read_csv('test_with_survived.csv', index_col=0)
test = age_imp_preprocess_data_title(test)

y_test = test['Survived']
X_test = test.drop(["Survived"], axis=1)

cat_features = np.where(X_train.dtypes != float)[0]

model = CatBoostClassifier(loss_function='Logloss', eval_metric='Accuracy', verbose=False, use_best_model=True, random_seed=42, cat_features=cat_features)
model.fit(X_train, y_train, eval_set=(X_test, y_test))

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.784688995215311

# %% [markdown]
# **Imputation combining titles and KNN**

# %%
def impute_age_KNNandTitle(data):

    # Make sure that the column 'Name' exists in the DataFrame.
    if 'Name' not in data.columns:
        raise KeyError("The column 'Name' does not exist in the DataFrame.")

    # Convert all strings in the 'Name' column to lowercase
    data['Name'] = data['Name'].str.lower()

    # Function to extract the title from the name
    def give_title(row):
        title = str(re.split(r'[,.]+', row['Name'])[1]).strip()
        return title

    # Applying the give_title function to extract titles
    data['Title'] = data.apply(give_title, axis=1)

    # Replace equivalent titles to unify
    data.replace({'Title': {'mlle': 'miss', 'ms': 'miss', 'mme': 'mrs'}}, inplace=True)

    label_encoder = LabelEncoder()
    data['Title'] = label_encoder.fit_transform(data['Title'])

    # Selection of relevant features to find nearby neighbors
    age_features = ['Pclass', 'SibSp', 'Parch', 'Fare', 'Sex', 'Title']

    # Subset of characteristics and age column
    age_data = data[age_features + ['Age']].copy()

    # Coding categorical variables
    le = LabelEncoder()
    age_data['Sex'] = le.fit_transform(age_data['Sex'])

    # Make sure that all columns are numeric.
    age_data = age_data.apply(pd.to_numeric, errors='coerce')

    # Create the KNN imputator
    imputer = KNNImputer(n_neighbors=10, weights='uniform')

    # Impute missing values in 'Age'.
    age_imputed = imputer.fit_transform(age_data)

    # Create a new DataFrame with the imputed values
    age_imputed_df = pd.DataFrame(age_imputed, columns=age_data.columns, index=age_data.index)

    # Assign the imputed values of 'Age' back to the original DataFrame
    data.loc[age_data.index, 'Age'] = age_imputed_df['Age']

# %%
# New preprocess data with new imputation function
def age_imp_preprocess_data_KNNandTitle(data):
    data = impute_age_KNN(data)
    data.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
    data['Fare'].fillna(data['Fare'].median(), inplace=True)
    data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})
    data = pd.get_dummies(data, columns=['Embarked'])
    return data

# %%
train = pd.read_csv("train.csv", index_col=0)
train = age_imp_preprocess_data_KNNandTitle(train)

y_train = train['Survived']
X_train = train.drop('Survived', axis=1)

test = pd.read_csv('test_with_survived.csv', index_col=0)
test = age_imp_preprocess_data_KNNandTitle(test)

y_test = test['Survived']
X_test = test.drop(["Survived"], axis=1)

cat_features = np.where(X_train.dtypes != float)[0]

model = CatBoostClassifier(loss_function='Logloss', eval_metric='Accuracy', verbose=False, use_best_model=True, random_seed=42, cat_features=cat_features)
model.fit(X_train, y_train, eval_set=(X_test, y_test))

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7942583732057417

# %% [markdown]
# ## **Feature engineering**

# %% [markdown]
# The model is capturing the 'Sex' interactions very well, therefore we need to add some variables to uncommon interactions to assume.
#
# Variables added and their porpuse:
# - Family: capture 'SibSp' and 'Parch' in one variable.
# - Alone+Pclass1: people traveling alone in first class. Why? because people traveling alone probably are more likely to die. But what could be the exception? people who were in 1st class.
# - Alone+Pclass3: Capture the group that are more likely to die.
#
# Variables deleted:
# - Deleted 'SibSp' and 'Parch' to avoid multicolinearity with 'Family'.

# %%
def fe_preprocess_data(data):
    data['Age'].fillna(data['Age'].median(), inplace=True)
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
    data['Sex'] = data['Sex'].map({'female': 1, 'male': 0})
    data["Fare"].fillna(data.groupby("Pclass")["Fare"].transform("median"), inplace=True)

    data["Age"] = data["Age"].apply(lambda x: x - 30)

    data["Family"] = np.where(data["SibSp"] + data["Parch"] > 0, "With Family", "Alone")
    data["Alone+Pclass1"] = np.where((data["Family"] == "Alone") & (data["Pclass"] == 1), 1, 0)
    data["Alone+Pclass3"] = np.where((data["Family"] == "Alone") & (data["Pclass"] == 3), 1, 0)

    data.drop(['Name', 'Ticket', 'Cabin', "SibSp", "Parch"], axis=1, inplace=True)

    data = pd.get_dummies(data, columns=['Embarked'])

    return data

# %% [markdown]
# Make the whole process again to test the model

# %%
train = pd.read_csv("train.csv", index_col=0)
train = fe_preprocess_data(train)

y_train = train['Survived']
X_train = train.drop('Survived', axis=1)

test = pd.read_csv('test_with_survived.csv', index_col=0)
test = fe_preprocess_data(test)

y_test = test['Survived']
X_test = test.drop(["Survived"], axis=1)

cat_features = np.where(X_train.dtypes != float)[0]

model = CatBoostClassifier(loss_function='Logloss', eval_metric='Accuracy', verbose=False, use_best_model=True, random_seed=42, cat_features=cat_features)
model.fit(X_train, y_train, eval_set=(X_test, y_test))

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7990430622009569

# %%
feature_importance = model.get_feature_importance(prettified=True)
feature_importance
# Out:
#       Feature Id  Importances
# 0            Sex    40.796367
# 1         Pclass    20.763163
# 2            Age    15.148694
# 3           Fare    13.189028
# 4  Alone+Pclass3     2.920780
# 5     Embarked_S     2.779462
# 6         Family     1.517881
# 7     Embarked_C     1.209415
# 8  Alone+Pclass1     0.958965
# 9     Embarked_Q     0.716247

# %% [markdown]
# Despite the fact that the model did not increase their accuracy we decided to keep the model like that so we can explore if the model can improve more in the hyperparameter tuning phase.

# %% [markdown]
# ## **Hyperparameter Tuning**

# %% [markdown]
# We are going to find the best parameters for the model using Optuna.
#
# Optuna does not use traditional grid search. Instead, it uses a more advanced and efficient approach called sequential model-based optimization (SMBO), with a focus on Tree-structured Parzen Estimator (TPE) as its default sampler.
#
# Optuna uses TPE to model the objective function. Instead of randomly selecting hyperparameters, it builds a probabilistic model that represents the relationship between hyperparameters and performance metrics (e.g., accuracy or loss).
#
# By using this method, Optuna avoids the exhaustive and time-consuming nature of grid search and is more effective than random search.

# %%
def objective(trial):
    # Define the hyperparameter search space
    params = {
        'depth': trial.suggest_int('depth', 1, 16),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.5, log=True),
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-2, 10, log=True),
        'border_count': trial.suggest_int('border_count', 1, 255),
        'random_strength': trial.suggest_float('random_strength', 1e-9, 10, log=True),
        'rsm': trial.suggest_float('rsm', 0.1, 1.0),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0.1, 10),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS', 'No']),
    }

    # Conditionally set bootstrap-related parameters
    if params['bootstrap_type'] == 'Bayesian':
        params['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0.0, 10.0)
    elif params['bootstrap_type'] in ['Bernoulli', 'MVS']:
        params['subsample'] = trial.suggest_float('subsample', 0.1, 1.0)

    # Initialize the model with the suggested hyperparameters
    model = CatBoostClassifier(
        loss_function='Logloss',
        eval_metric='Accuracy',
        verbose=False,
        random_seed=42,
        **params
    )

    # Fit the model
    model.fit(Pool(X_train, y_train, cat_features=cat_features), eval_set=(X_test, y_test))

    # Predict and calculate accuracy
    preds = model.predict(X_test)
    accuracy = accuracy_score(y_test, preds)

    return accuracy

# Optimize using Optuna
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=10))
study.optimize(objective, n_trials=100)

# Extract the best hyperparameters
best_params = study.best_params

# Train the final model with the best hyperparameters
best_model = CatBoostClassifier(
    loss_function='Logloss',
    eval_metric='Accuracy',
    random_seed=42,
    verbose=False,
    **best_params
)

best_model.fit(X_train, y_train, cat_features=cat_features, eval_set=(X_test, y_test))
best_y_pred = best_model.predict(X_test)

# Evaluate the final model
final_accuracy = accuracy_score(y_test, best_y_pred)
print(f"Best accuracy: {final_accuracy}")
# Out:
# [I 2024-09-09 20:42:50,409] A new study created in memory with name: no-name-e6d99e7d-64d5-48b5-b474-d74ff765aa2c
# [I 2024-09-09 20:42:58,111] Trial 0 finished with value: 0.4258373205741627 and parameters: {'depth': 13, 'learning_rate': 0.0001193330767726717, 'iterations': 670, 'l2_leaf_reg': 1.7636469336159117, 'border_count': 128, 'random_strength': 1.7699722412548123e-07, 'rsm': 0.27825657828366157, 'scale_pos_weight': 7.629254050769691, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8313588654869022}. Best is trial 0 with value: 0.4258373205741627.
# ...

# %%
# Save the best model with pickle
import pickle

with open('best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

# %%
# Best accuracy for Seed = 1: 0.8038277511961722, 7m with GPU
# Best accuracy for Seed = 10: 0.80622009569378, 10m with CPU

# %%
# Check if PassengerId exists, otherwise use the index
if 'PassengerId' in test.columns:
    df = pd.DataFrame({'PassengerId': test['PassengerId'], 'Survived': best_y_pred})
else:
    df = pd.DataFrame({'PassengerId': test.index, 'Survived': best_y_pred})

# Save to CSV in the required format
df.to_csv('submission.csv', index=False)
files.download('submission.csv')
